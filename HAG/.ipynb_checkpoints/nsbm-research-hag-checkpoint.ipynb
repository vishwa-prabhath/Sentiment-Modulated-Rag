# %%
# !pip install chromadb transformers
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
# Out:
# Requirement already satisfied: chromadb in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.6.3)
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (4.48.0)
# Requirement already satisfied: build>=1.0.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (2.10.5)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (0.115.10)
# Requirement already satisfied: uvicorn>=0.18.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (3.18.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers) (0.27.1)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers) (0.5.2)
# Requirement already satisfied: pyproject_hooks in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (7.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastapi>=0.95.2->chromadb) (0.46.0)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (4.8.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.12.0)
# Requirement already satisfied: six>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Requirement already satisfied: durationpy>=0.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.68.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.4.1)
# Requirement already satisfied: monotonic>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->transformers) (3.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: click>=8.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0)
# Requirement already satisfied: zipp>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.17.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Load tokenizer and model (GPT2 for generation)
model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Load emotion classifier
classifier = pipeline("text-classification", model="bhadresh-savani/distilbert-base-uncased-emotion")
def dynamic_hyperparameter_selector(task_type: str):
    if task_type == "factual":
        return {"temperature": 0.3, "top_p": 0.85, "top_k": 40, "repetition_penalty": 1.2}
    elif task_type == "creative":
        return {"temperature": 0.95, "top_p": 0.95, "top_k": 100, "repetition_penalty": 1.0}
    elif task_type == "emotional":
        return {"temperature": 0.7, "top_p": 0.9, "top_k": 50, "repetition_penalty": 1.1}
    else:
        return {"temperature": 0.5, "top_p": 0.85, "top_k": 60, "repetition_penalty": 1.1}
# Out:
# Device set to use mps:0

# %%
def infer_task_type(prompt):
    result = classifier(prompt)[0]['label']
    if result in ["joy", "surprise"]:
        return "creative"
    elif result in ["sadness", "fear", "love"]:
        return "emotional"
    else:
        return "factual"

# %%
def generate_response(prompt: str):
    task_type = infer_task_type(prompt)
    hyperparams = dynamic_hyperparameter_selector(task_type)
    inputs = tokenizer(prompt, return_tensors="pt")
    output = model.generate(
        **inputs,
        do_sample=True,
        temperature=hyperparams["temperature"],
        top_p=hyperparams["top_p"],
        top_k=hyperparams["top_k"],
        repetition_penalty=hyperparams["repetition_penalty"],
        max_length=200,
        pad_token_id=tokenizer.eos_token_id
    )
    return tokenizer.decode(output[0], skip_special_tokens=True), task_type

# %%
if __name__ == "__main__":
    prompt = input("Enter your prompt: ")
    response, task_type = generate_response(prompt)
    print(f"\n[Task Type: {task_type}]\n")
    print(response)

# %% [markdown]
# # Anton 06/19

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch
import collections 
from chromaDB_logger import store_to_chroma

# --- Configuration ---
MEMORY_SIZE = 3 # How many past sets of hyperparameters to remember
CURRENT_TASK_WEIGHT = 0.7 # How much the current task type influences the new hyperparameters
PREVIOUS_MEMORY_WEIGHT = 0.3 # How much the average of past hyperparameters influences the new ones

model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

classifier = pipeline("text-classification", model="bhadresh-savani/distilbert-base-uncased-emotion")

# Initialize hyperparameter memory using a deque for fixed-size history
hyperparameter_memory = collections.deque(maxlen=MEMORY_SIZE)

# Vishwa's Function
def dynamic_hyperparameter_selector(task_type: str):
    """
    Selects a base set of hyperparameters based on the task type.
    These are the 'target' hyperparameters for the current prompt.
    """
    if task_type == "factual":
        return {"temperature": 0.3, "top_p": 0.85, "top_k": 40, "repetition_penalty": 1.2}
    elif task_type == "creative":
        return {"temperature": 0.95, "top_p": 0.95, "top_k": 100, "repetition_penalty": 1.0}
    elif task_type == "emotional":
        return {"temperature": 0.7, "top_p": 0.9, "top_k": 50, "repetition_penalty": 1.1}
    else: 
        return {"temperature": 0.5, "top_p": 0.85, "top_k": 60, "repetition_penalty": 1.1}

def infer_task_type(prompt: str) -> str:
    """
    Infers the task type based on the prompt's emotional content.
    """
    result = classifier(prompt)[0]['label']
    if result in ["joy", "surprise"]:
        return "creative"
    elif result in ["sadness", "fear", "love"]:
        return "emotional"
    else:
        return "factual"

# Hyper Parameter Smoothing function -- Anton
def smooth_hyperparameters(current_task_params: dict, memory: collections.deque) -> dict:
    
    if not memory:
        print("Memory is empty. Using direct task parameters.")
        return current_task_params

    avg_memory_params = {
        "temperature": 0.0,
        "top_p": 0.0,
        "top_k": 0.0,
        "repetition_penalty": 0.0
    }

    for past_params in memory:
        for key in avg_memory_params:
            avg_memory_params[key] += past_params[key]

    for key in avg_memory_params:
        avg_memory_params[key] /= len(memory)

    # Apply the weighted average to smooth the parameters
    smoothed_params = {
        "temperature": (current_task_params["temperature"] * CURRENT_TASK_WEIGHT) +
                       (avg_memory_params["temperature"] * PREVIOUS_MEMORY_WEIGHT),
        "top_p": (current_task_params["top_p"] * CURRENT_TASK_WEIGHT) +
                 (avg_memory_params["top_p"] * PREVIOUS_MEMORY_WEIGHT),
        "top_k": int((current_task_params["top_k"] * CURRENT_TASK_WEIGHT) +
                     (avg_memory_params["top_k"] * PREVIOUS_MEMORY_WEIGHT)), 
        "repetition_penalty": (current_task_params["repetition_penalty"] * CURRENT_TASK_WEIGHT) +
                              (avg_memory_params["repetition_penalty"] * PREVIOUS_MEMORY_WEIGHT)
    }

    # Add constraints to ensure parameters stay within reasonable bounds
    smoothed_params["temperature"] = max(0.1, min(smoothed_params["temperature"], 1.0))
    smoothed_params["top_p"] = max(0.1, min(smoothed_params["top_p"], 1.0))
    smoothed_params["top_k"] = max(1, min(smoothed_params["top_k"], tokenizer.vocab_size - 1)) # top_k can't exceed vocab size
    smoothed_params["repetition_penalty"] = max(1.0, min(smoothed_params["repetition_penalty"], 2.0)) # A common range

    return smoothed_params

def generate_response(prompt: str):
    global hyperparameter_memory # Declare intent to modify the global variable

    task_type = infer_task_type(prompt)
    
    # Get the target hyperparameters for the current task
    current_task_target_params = dynamic_hyperparameter_selector(task_type)

    # Smooth these target parameters with the memory
    final_hyperparams = smooth_hyperparameters(current_task_target_params, hyperparameter_memory)

    hyperparameter_memory.append(final_hyperparams)

    print(f"\nDebug Info:")
    print(f"  Inferred Task Type: {task_type}")
    print(f"  Current Task Target Hyperparams: {current_task_target_params}")
    print(f"  Smoothed/Final Hyperparams Used: {final_hyperparams}")
    print(f"  Current Memory State ({len(hyperparameter_memory)} entries): {list(hyperparameter_memory)}")

    # updating the model to bypass the vague response generation Issue - Anton
    new_prompt = "Assume that you are an Ai agent Answering a question\n Question: \" "+prompt +"\""
    inputs = tokenizer(new_prompt, return_tensors="pt")
    output = model.generate(
        **inputs,
        do_sample=True,
        temperature=final_hyperparams["temperature"],
        top_p=final_hyperparams["top_p"],
        top_k=final_hyperparams["top_k"],
        repetition_penalty=final_hyperparams["repetition_penalty"],
        max_length=200,
        pad_token_id=tokenizer.eos_token_id
    )
    return tokenizer.decode(output[0], skip_special_tokens=True), task_type

if __name__ == "__main__":
    print("Welcome to the Dynamic Hyperparameter AI Chatbot!")
    print("Type 'quit' or 'exit' to end the conversation.")

    # starting with a 'neutral' base:
    initial_params = {"temperature": 0.5, "top_p": 0.85, "top_k": 60, "repetition_penalty": 1.1}
    hyperparameter_memory.append(initial_params)
    print(f"Initial Memory State: {list(hyperparameter_memory)}")


    while True:
        prompt = input("\nEnter your prompt: ")
        if prompt.lower() in ['quit', 'exit']:
            print("Exiting chat. Goodbye!")
            break

        response, task_type = generate_response(prompt)
        print(f"\n[Inferred Task Type: {task_type}]")
        print(f"Response: {response}")

        # Log this interaction in ChromaDB
        store_to_chroma(prompt, response, task_type)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 import torch
#       3 import collections
# ----> 4 from chromaDB_logger import store_to_chroma
#       6 # --- Configuration ---
#       7 MEMORY_SIZE = 3 # How many past sets of hyperparameters to remember
#
# File ~/Desktop/HAG V2/chromaDB_logger.py:7
#       4 import uuid
#       6 # Initialize ChromaDB client and collection
# ----> 7 client = chromadb.Client(Settings(chroma_db_impl="duckdb+parquet", persist_directory="./chroma_store"))
#       8 collection = client.get_or_create_collection(name="llm_knowledge")
#      10 # Load embedding model
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/chromadb/__init__.py:333, in Client(settings, tenant, database)
#     330 tenant = str(tenant)
#     331 database = str(database)
# --> 333 return ClientCreator(tenant=tenant, database=database, settings=settings)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/chromadb/api/client.py:58, in Client.__init__(self, tenant, database, settings)
#      52 def __init__(
#      53     self,
#      54     tenant: str = DEFAULT_TENANT,
#      55     database: str = DEFAULT_DATABASE,
#      56     settings: Settings = Settings(),
#      57 ) -> None:
# ---> 58     super().__init__(settings=settings)
#      59     self.tenant = tenant
#      60     self.database = database
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/chromadb/api/shared_system_client.py:19, in SharedSystemClient.__init__(self, settings)
#      14 def __init__(
#      15     self,
#      16     settings: Settings = Settings(),
#      17 ) -> None:
#      18     self._identifier = SharedSystemClient._get_identifier_from_settings(settings)
# ---> 19     SharedSystemClient._create_system_if_not_exists(self._identifier, settings)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/chromadb/api/shared_system_client.py:26, in SharedSystemClient._create_system_if_not_exists(cls, identifier, settings)
#      21 @classmethod
#      22 def _create_system_if_not_exists(
#      23     cls, identifier: str, settings: Settings
#      24 ) -> System:
#      25     if identifier not in cls._identifier_to_system:
# ---> 26         new_system = System(settings)
#      27         cls._identifier_to_system[identifier] = new_system
#      29         new_system.instance(ProductTelemetryClient)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/chromadb/config.py:363, in System.__init__(self, settings)
#     361 # Validate settings don't contain any legacy config values
#     362 for key in _legacy_config_keys:
# --> 363     if settings[key] is not None:
#     364         raise ValueError(LEGACY_ERROR)
#     366 if (
#     367     settings["chroma_segment_cache_policy"] is not None
#     368     and settings["chroma_segment_cache_policy"] != "LRU"
#     369 ):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/chromadb/config.py:297, in Settings.__getitem__(self, key)
#     295 # Error on legacy config values
#     296 if isinstance(val, str) and val in _legacy_config_values:
# --> 297     raise ValueError(LEGACY_ERROR)
#     298 return val
#
# ValueError: You are using a deprecated configuration of Chroma.
#
# If you do not have data you wish to migrate, you only need to change how you construct
# your Chroma client. Please see the "New Clients" section of https://docs.trychroma.com/deployment/migration.
# ________________________________________________________________________________________________
#
# If you do have data you wish to migrate, we have a migration tool you can use in order to
# migrate your data to the new Chroma architecture.
# Please `pip install chroma-migrate` and run `chroma-migrate` to migrate your data and then
# change how you construct your Chroma client.
#
# See https://docs.trychroma.com/deployment/migration for more information or join our discord at https://discord.gg/MMeYNTmh3x for help!

# %% [markdown]
# # Vishwa & Ometh - Chromadb Implementation + Graph Generation 6/20

# %% [markdown]
# > ChromaDB

# %%
from chromadb import PersistentClient
from chromadb.config import Settings
from sentence_transformers import SentenceTransformer
import uuid
client = PersistentClient(path="./chroma_store")
collection = client.get_or_create_collection(name="llm_knowledge")


# Load embedding model
embedder = SentenceTransformer("all-MiniLM-L6-v2")

def store_to_chroma(prompt, response, task_type):
    # Combine prompt and response for embedding
    print("ChromaClient Is beign used !")
    text_to_embed = f"Prompt: {prompt}\nResponse: {response}"
    embedding = embedder.encode(text_to_embed).tolist()

    collection.add(
        documents=[text_to_embed],
        embeddings=[embedding],
        metadatas=[{"task_type": task_type}],
        ids=[str(uuid.uuid4())]
    )

    print("✅ Stored in ChromaDB")

# %%
factual_prompts = [
    "What are the main causes of climate change?",
    "Explain how blockchain technology works.",
    "Who was the first person to walk on the moon?",
    "How does photosynthesis work in plants?",
    "What are the key differences between RAM and ROM?",
    "Describe the structure of a human cell.",
    "List the planets in the solar system in order.",
    "What is Newton's second law of motion?",
    "Define artificial intelligence in simple terms.",
    "What are the benefits of electric vehicles over gas ones?"
]

creative_prompts = [
    "Write a short story about a time-traveling detective.",
    "Invent a new fruit and describe its uses.",
    "Imagine a planet made entirely of water. Describe a day there.",
    "Create a poem about a robot finding its soul.",
    "Write a dialogue between a spoon and a fork arguing over soup.",
    "Design a new superhero with absurd powers.",
    "Describe a city in the sky run by birds.",
    "Tell a bedtime story about a pirate and a talking map.",
    "What would happen if gravity randomly turned off for 5 minutes?",
    "Narrate a dream from the perspective of a cloud."
]

emotional_prompts = [
    "I feel like I’m not good enough. What should I do?",
    "How do I deal with losing someone I love?",
    "I’m really nervous about my job interview tomorrow.",
    "Why does loneliness hurt so much?",
    "I’m feeling overwhelmed with happiness today.",
    "Sometimes I feel like no one understands me. Why is that?",
    "How can I recover from a heartbreak?",
    "I’m afraid of failing. What can I do?",
    "I’m so excited to start college. Any advice?",
    "Why do I cry when I’m angry?"
]

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch
import collections



logs = []

# from chromaDB_logger import store_to_chroma

# --- Configuration ---
MEMORY_SIZE = 3 # How many past sets of hyperparameters to remember
CURRENT_TASK_WEIGHT = 0.7 # How much the current task type influences the new hyperparameters
PREVIOUS_MEMORY_WEIGHT = 0.3 # How much the average of past hyperparameters influences the new ones

# Added missing GPU Acceleration Functionality
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_name = "cognitivecomputations/Dolphin3.0-Llama3.2-3B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name).to(device)


classifier = pipeline("text-classification", model="bhadresh-savani/distilbert-base-uncased-emotion")

# Initialize hyperparameter memory using a deque for fixed-size history
hyperparameter_memory = collections.deque(maxlen=MEMORY_SIZE)

# Vishwa's Function
def dynamic_hyperparameter_selector(task_type: str):
    """
    Selects a base set of hyperparameters based on the task type.
    These are the 'target' hyperparameters for the current prompt.
    """
    if task_type == "factual":
        return {"temperature": 0.3, "top_p": 0.85, "top_k": 40, "repetition_penalty": 1.2}
    elif task_type == "creative":
        return {"temperature": 0.95, "top_p": 0.95, "top_k": 100, "repetition_penalty": 1.0}
    elif task_type == "emotional":
        return {"temperature": 0.7, "top_p": 0.9, "top_k": 50, "repetition_penalty": 1.1}
    else: 
        return {"temperature": 0.5, "top_p": 0.85, "top_k": 60, "repetition_penalty": 1.1}

def infer_task_type(prompt: str) -> str:
    """
    Infers the task type based on the prompt's emotional content.
    """
    result = classifier(prompt)[0]['label']
    if result in ["joy", "surprise"]:
        return "creative"
    elif result in ["sadness", "fear", "love"]:
        return "emotional"
    else:
        return "factual"

# Hyper Parameter Smoothing function -- Anton
def smooth_hyperparameters(current_task_params: dict, memory: collections.deque) -> dict:
    
    if not memory:
        print("Memory is empty. Using direct task parameters.")
        return current_task_params

    avg_memory_params = {
        "temperature": 0.0,
        "top_p": 0.0,
        "top_k": 0.0,
        "repetition_penalty": 0.0
    }

    for past_params in memory:
        for key in avg_memory_params:
            avg_memory_params[key] += past_params[key]

    for key in avg_memory_params:
        avg_memory_params[key] /= len(memory)

    # Apply the weighted average to smooth the parameters
    smoothed_params = {
        "temperature": (current_task_params["temperature"] * CURRENT_TASK_WEIGHT) +
                       (avg_memory_params["temperature"] * PREVIOUS_MEMORY_WEIGHT),
        "top_p": (current_task_params["top_p"] * CURRENT_TASK_WEIGHT) +
                 (avg_memory_params["top_p"] * PREVIOUS_MEMORY_WEIGHT),
        "top_k": int((current_task_params["top_k"] * CURRENT_TASK_WEIGHT) +
                     (avg_memory_params["top_k"] * PREVIOUS_MEMORY_WEIGHT)), 
        "repetition_penalty": (current_task_params["repetition_penalty"] * CURRENT_TASK_WEIGHT) +
                              (avg_memory_params["repetition_penalty"] * PREVIOUS_MEMORY_WEIGHT)
    }

    # Add constraints to ensure parameters stay within reasonable bounds
    smoothed_params["temperature"] = max(0.1, min(smoothed_params["temperature"], 1.0))
    smoothed_params["top_p"] = max(0.1, min(smoothed_params["top_p"], 1.0))
    smoothed_params["top_k"] = max(1, min(smoothed_params["top_k"], tokenizer.vocab_size - 1)) # top_k can't exceed vocab size
    smoothed_params["repetition_penalty"] = max(1.0, min(smoothed_params["repetition_penalty"], 2.0)) # A common range

    return smoothed_params

def generate_response(prompt: str):
    global hyperparameter_memory # Declare intent to modify the global variable

    task_type = infer_task_type(prompt)
    
    # Get the target hyperparameters for the current task
    current_task_target_params = dynamic_hyperparameter_selector(task_type)

    # Smooth these target parameters with the memory
    final_hyperparams = smooth_hyperparameters(current_task_target_params, hyperparameter_memory)

    hyperparameter_memory.append(final_hyperparams)

    print(f"\nDebug Info:")
    print(f"  Inferred Task Type: {task_type}")
    print(f"  Current Task Target Hyperparams: {current_task_target_params}")
    print(f"  Smoothed/Final Hyperparams Used: {final_hyperparams}")
    print(f"  Current Memory State ({len(hyperparameter_memory)} entries): {list(hyperparameter_memory)}")

    # updating the model to bypass the vague response generation Issue - Anton
    new_prompt = "Assume that you are an Ai agent Answering a question\n Question: \" "+prompt +"\""
    inputs = tokenizer(new_prompt, return_tensors="pt").to(device)
    output = model.generate(
        **inputs,
        do_sample=True,
        temperature=final_hyperparams["temperature"],
        top_p=final_hyperparams["top_p"],
        top_k=final_hyperparams["top_k"],
        repetition_penalty=final_hyperparams["repetition_penalty"],
        max_length=200,
        pad_token_id=tokenizer.eos_token_id
    )
    logs.append({
        "task_type": task_type,
        "temperature": final_hyperparams["temperature"],
        "top_p": final_hyperparams["top_p"],
        "top_k": final_hyperparams["top_k"],
        "repetition_penalty": final_hyperparams["repetition_penalty"]
    })
    return tokenizer.decode(output[0], skip_special_tokens=True), task_type

if __name__ == "__main__":
    print("Welcome to the Dynamic Hyperparameter AI Chatbot!")
    print("Type 'quit' or 'exit' to end the conversation.")

    # starting with a 'neutral' base:
    initial_params = {"temperature": 0.5, "top_p": 0.85, "top_k": 60, "repetition_penalty": 1.1}
    hyperparameter_memory.append(initial_params)
    print(f"Initial Memory State: {list(hyperparameter_memory)}")


    # while True:
    #     prompt = input("\nEnter your prompt: ")
    #     if prompt.lower() in ['quit', 'exit']:
    #         print("Exiting chat. Goodbye!")
    #         break

    #     response, task_type = generate_response(prompt)
    #     print(f"\n[Inferred Task Type: {task_type}]")
    #     print(f"Response: {response}")

    #     # Log this interaction in ChromaDB
    #     store_to_chroma(prompt, response, task_type)

    # Initialize Automation
    for prompt in factual_prompts:
        generate_response(prompt)

    for prompt in creative_prompts:
        generate_response(prompt)
    
    for prompt in emotional_prompts:
        generate_response(prompt)
# Out:
# tokenizer_config.json:   0%|          | 0.00/53.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/935 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/206 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/768 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cuda:0
# Welcome to the Dynamic Hyperparameter AI Chatbot!
# Type 'quit' or 'exit' to end the conversation.
# Initial Memory State: [{'temperature': 0.5, 'top_p': 0.85, 'top_k': 60, 'repetition_penalty': 1.1}]
#
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.36, 'top_p': 0.85, 'top_k': 46, 'repetition_penalty': 1.17}
#   Current Memory State (2 entries): [{'temperature': 0.5, 'top_p': 0.85, 'top_k': 60, 'repetition_penalty': 1.1}, {'temperature': 0.36, 'top_p': 0.85, 'top_k': 46, 'repetition_penalty': 1.17}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.7939999999999999, 'top_p': 0.9199999999999999, 'top_k': 85, 'repetition_penalty': 1.0405}
#   Current Memory State (3 entries): [{'temperature': 0.5, 'top_p': 0.85, 'top_k': 60, 'repetition_penalty': 1.1}, {'temperature': 0.36, 'top_p': 0.85, 'top_k': 46, 'repetition_penalty': 1.17}, {'temperature': 0.7939999999999999, 'top_p': 0.9199999999999999, 'top_k': 85, 'repetition_penalty': 1.0405}]
#
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.37539999999999996, 'top_p': 0.857, 'top_k': 47, 'repetition_penalty': 1.17105}
#   Current Memory State (3 entries): [{'temperature': 0.36, 'top_p': 0.85, 'top_k': 46, 'repetition_penalty': 1.17}, {'temperature': 0.7939999999999999, 'top_p': 0.9199999999999999, 'top_k': 85, 'repetition_penalty': 1.0405}, {'temperature': 0.37539999999999996, 'top_p': 0.857, 'top_k': 47, 'repetition_penalty': 1.17105}]
#
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.36293999999999993, 'top_p': 0.8576999999999999, 'top_k': 45, 'repetition_penalty': 1.1781549999999998}
#   Current Memory State (3 entries): [{'temperature': 0.7939999999999999, 'top_p': 0.9199999999999999, 'top_k': 85, 'repetition_penalty': 1.0405}, {'temperature': 0.37539999999999996, 'top_p': 0.857, 'top_k': 47, 'repetition_penalty': 1.17105}, {'temperature': 0.36293999999999993, 'top_p': 0.8576999999999999, 'top_k': 45, 'repetition_penalty': 1.1781549999999998}]
#
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.363234, 'top_p': 0.8584699999999998, 'top_k': 45, 'repetition_penalty': 1.1789705}
#   Current Memory State (3 entries): [{'temperature': 0.37539999999999996, 'top_p': 0.857, 'top_k': 47, 'repetition_penalty': 1.17105}, {'temperature': 0.36293999999999993, 'top_p': 0.8576999999999999, 'top_k': 45, 'repetition_penalty': 1.1781549999999998}, {'temperature': 0.363234, 'top_p': 0.8584699999999998, 'top_k': 45, 'repetition_penalty': 1.1789705}]
#
# Debug Info:
#   Inferred Task Type: emotional
#   Current Task Target Hyperparams: {'temperature': 0.7, 'top_p': 0.9, 'top_k': 50, 'repetition_penalty': 1.1}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.6001574, 'top_p': 0.8873169999999999, 'top_k': 48, 'repetition_penalty': 1.12281755}
#   Current Memory State (3 entries): [{'temperature': 0.36293999999999993, 'top_p': 0.8576999999999999, 'top_k': 45, 'repetition_penalty': 1.1781549999999998}, {'temperature': 0.363234, 'top_p': 0.8584699999999998, 'top_k': 45, 'repetition_penalty': 1.1789705}, {'temperature': 0.6001574, 'top_p': 0.8873169999999999, 'top_k': 48, 'repetition_penalty': 1.12281755}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.7976331399999999, 'top_p': 0.9253486999999998, 'top_k': 83, 'repetition_penalty': 1.0479943049999998}
#   Current Memory State (3 entries): [{'temperature': 0.363234, 'top_p': 0.8584699999999998, 'top_k': 45, 'repetition_penalty': 1.1789705}, {'temperature': 0.6001574, 'top_p': 0.8873169999999999, 'top_k': 48, 'repetition_penalty': 1.12281755}, {'temperature': 0.7976331399999999, 'top_p': 0.9253486999999998, 'top_k': 83, 'repetition_penalty': 1.0479943049999998}]
#
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.386102454, 'top_p': 0.86211357, 'top_k': 45, 'repetition_penalty': 1.1749782354999998}
#   Current Memory State (3 entries): [{'temperature': 0.6001574, 'top_p': 0.8873169999999999, 'top_k': 48, 'repetition_penalty': 1.12281755}, {'temperature': 0.7976331399999999, 'top_p': 0.9253486999999998, 'top_k': 83, 'repetition_penalty': 1.0479943049999998}, {'temperature': 0.386102454, 'top_p': 0.86211357, 'top_k': 45, 'repetition_penalty': 1.1749782354999998}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.8433892993999998, 'top_p': 0.9324779269999999, 'top_k': 87, 'repetition_penalty': 1.0345790090499998}
#   Current Memory State (3 entries): [{'temperature': 0.7976331399999999, 'top_p': 0.9253486999999998, 'top_k': 83, 'repetition_penalty': 1.0479943049999998}, {'temperature': 0.386102454, 'top_p': 0.86211357, 'top_k': 45, 'repetition_penalty': 1.1749782354999998}, {'temperature': 0.8433892993999998, 'top_p': 0.9324779269999999, 'top_k': 87, 'repetition_penalty': 1.0345790090499998}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.8677124893399999, 'top_p': 0.9369940197, 'top_k': 91, 'repetition_penalty': 1.025755154955}
#   Current Memory State (3 entries): [{'temperature': 0.386102454, 'top_p': 0.86211357, 'top_k': 45, 'repetition_penalty': 1.1749782354999998}, {'temperature': 0.8433892993999998, 'top_p': 0.9324779269999999, 'top_k': 87, 'repetition_penalty': 1.0345790090499998}, {'temperature': 0.8677124893399999, 'top_p': 0.9369940197, 'top_k': 91, 'repetition_penalty': 1.025755154955}]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.41972042427399997, 'top_p': 0.8681585516699999, 'top_k': 50, 'repetition_penalty': 1.1635312399504998}
#   Current Memory State (3 entries): [{'temperature': 0.8433892993999998, 'top_p': 0.9324779269999999, 'top_k': 87, 'repetition_penalty': 1.0345790090499998}, {'temperature': 0.8677124893399999, 'top_p': 0.9369940197, 'top_k': 91, 'repetition_penalty': 1.025755154955}, {'temperature': 0.41972042427399997, 'top_p': 0.8681585516699999, 'top_k': 50, 'repetition_penalty': 1.1635312399504998}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.8780822213013999, 'top_p': 0.9387630498369999, 'top_k': 92, 'repetition_penalty': 1.0223865403955499}
#   Current Memory State (3 entries): [{'temperature': 0.8677124893399999, 'top_p': 0.9369940197, 'top_k': 91, 'repetition_penalty': 1.025755154955}, {'temperature': 0.41972042427399997, 'top_p': 0.8681585516699999, 'top_k': 50, 'repetition_penalty': 1.1635312399504998}, {'temperature': 0.8780822213013999, 'top_p': 0.9387630498369999, 'top_k': 92, 'repetition_penalty': 1.0223865403955499}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.8815515134915399, 'top_p': 0.9393915621206999, 'top_k': 93, 'repetition_penalty': 1.0211672935301048}
#   Current Memory State (3 entries): [{'temperature': 0.41972042427399997, 'top_p': 0.8681585516699999, 'top_k': 50, 'repetition_penalty': 1.1635312399504998}, {'temperature': 0.8780822213013999, 'top_p': 0.9387630498369999, 'top_k': 92, 'repetition_penalty': 1.0223865403955499}, {'temperature': 0.8815515134915399, 'top_p': 0.9393915621206999, 'top_k': 93, 'repetition_penalty': 1.0211672935301048}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.8829354159066939, 'top_p': 0.9396313163627699, 'top_k': 93, 'repetition_penalty': 1.0207085073876154}
#   Current Memory State (3 entries): [{'temperature': 0.8780822213013999, 'top_p': 0.9387630498369999, 'top_k': 92, 'repetition_penalty': 1.0223865403955499}, {'temperature': 0.8815515134915399, 'top_p': 0.9393915621206999, 'top_k': 93, 'repetition_penalty': 1.0211672935301048}, {'temperature': 0.8829354159066939, 'top_p': 0.9396313163627699, 'top_k': 93, 'repetition_penalty': 1.0207085073876154}]
#
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.47425691506996337, 'top_p': 0.8767785928320468, 'top_k': 55, 'repetition_penalty': 1.146426234131327}
#   Current Memory State (3 entries): [{'temperature': 0.8815515134915399, 'top_p': 0.9393915621206999, 'top_k': 93, 'repetition_penalty': 1.0211672935301048}, {'temperature': 0.8829354159066939, 'top_p': 0.9396313163627699, 'top_k': 93, 'repetition_penalty': 1.0207085073876154}, {'temperature': 0.47425691506996337, 'top_p': 0.8767785928320468, 'top_k': 55, 'repetition_penalty': 1.146426234131327}]
#
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.4338743844468197, 'top_p': 0.8705801471315515, 'top_k': 52, 'repetition_penalty': 1.1588302035049047}
#   Current Memory State (3 entries): [{'temperature': 0.8829354159066939, 'top_p': 0.9396313163627699, 'top_k': 93, 'repetition_penalty': 1.0207085073876154}, {'temperature': 0.47425691506996337, 'top_p': 0.8767785928320468, 'top_k': 55, 'repetition_penalty': 1.146426234131327}, {'temperature': 0.4338743844468197, 'top_p': 0.8705801471315515, 'top_k': 52, 'repetition_penalty': 1.1588302035049047}]
#
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.3891066715423477, 'top_p': 0.8636990056326368, 'top_k': 48, 'repetition_penalty': 1.1725964945023846}
#   Current Memory State (3 entries): [{'temperature': 0.47425691506996337, 'top_p': 0.8767785928320468, 'top_k': 55, 'repetition_penalty': 1.146426234131327}, {'temperature': 0.4338743844468197, 'top_p': 0.8705801471315515, 'top_k': 52, 'repetition_penalty': 1.1588302035049047}, {'temperature': 0.3891066715423477, 'top_p': 0.8636990056326368, 'top_k': 48, 'repetition_penalty': 1.1725964945023846}]
#
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.33972379710591305, 'top_p': 0.8561057745596234, 'top_k': 43, 'repetition_penalty': 1.1877852932138615}
#   Current Memory State (3 entries): [{'temperature': 0.4338743844468197, 'top_p': 0.8705801471315515, 'top_k': 52, 'repetition_penalty': 1.1588302035049047}, {'temperature': 0.3891066715423477, 'top_p': 0.8636990056326368, 'top_k': 48, 'repetition_penalty': 1.1725964945023846}, {'temperature': 0.33972379710591305, 'top_p': 0.8561057745596234, 'top_k': 43, 'repetition_penalty': 1.1877852932138615}]
#
# Debug Info:
#   Inferred Task Type: emotional
#   Current Task Target Hyperparams: {'temperature': 0.7, 'top_p': 0.9, 'top_k': 50, 'repetition_penalty': 1.1}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.606270485309508, 'top_p': 0.8890384927323811, 'top_k': 49, 'repetition_penalty': 1.1219211991221152}
#   Current Memory State (3 entries): [{'temperature': 0.3891066715423477, 'top_p': 0.8636990056326368, 'top_k': 48, 'repetition_penalty': 1.1725964945023846}, {'temperature': 0.33972379710591305, 'top_p': 0.8561057745596234, 'top_k': 43, 'repetition_penalty': 1.1877852932138615}, {'temperature': 0.606270485309508, 'top_p': 0.8890384927323811, 'top_k': 49, 'repetition_penalty': 1.1219211991221152}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.7985100953957768, 'top_p': 0.9258843272924641, 'top_k': 84, 'repetition_penalty': 1.048230298683836}
#   Current Memory State (3 entries): [{'temperature': 0.33972379710591305, 'top_p': 0.8561057745596234, 'top_k': 43, 'repetition_penalty': 1.1877852932138615}, {'temperature': 0.606270485309508, 'top_p': 0.8890384927323811, 'top_k': 49, 'repetition_penalty': 1.1219211991221152}, {'temperature': 0.7985100953957768, 'top_p': 0.9258843272924641, 'top_k': 84, 'repetition_penalty': 1.048230298683836}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.8394504377811197, 'top_p': 0.9321028594584468, 'top_k': 87, 'repetition_penalty': 1.0357936791019813}
#   Current Memory State (3 entries): [{'temperature': 0.606270485309508, 'top_p': 0.8890384927323811, 'top_k': 49, 'repetition_penalty': 1.1219211991221152}, {'temperature': 0.7985100953957768, 'top_p': 0.9258843272924641, 'top_k': 84, 'repetition_penalty': 1.048230298683836}, {'temperature': 0.8394504377811197, 'top_p': 0.9321028594584468, 'top_k': 87, 'repetition_penalty': 1.0357936791019813}]
#
# Debug Info:
#   Inferred Task Type: emotional
#   Current Task Target Hyperparams: {'temperature': 0.7, 'top_p': 0.9, 'top_k': 50, 'repetition_penalty': 1.1}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.7144231018486403, 'top_p': 0.9047025679483292, 'top_k': 57, 'repetition_penalty': 1.0905945176907932}
#   Current Memory State (3 entries): [{'temperature': 0.7985100953957768, 'top_p': 0.9258843272924641, 'top_k': 84, 'repetition_penalty': 1.048230298683836}, {'temperature': 0.8394504377811197, 'top_p': 0.9321028594584468, 'top_k': 87, 'repetition_penalty': 1.0357936791019813}, {'temperature': 0.7144231018486403, 'top_p': 0.9047025679483292, 'top_k': 57, 'repetition_penalty': 1.0905945176907932}]
#
# Debug Info:
#   Inferred Task Type: emotional
#   Current Task Target Hyperparams: {'temperature': 0.7, 'top_p': 0.9, 'top_k': 50, 'repetition_penalty': 1.1}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.7252383635025537, 'top_p': 0.906268975469924, 'top_k': 57, 'repetition_penalty': 1.0874618495476611}
#   Current Memory State (3 entries): [{'temperature': 0.8394504377811197, 'top_p': 0.9321028594584468, 'top_k': 87, 'repetition_penalty': 1.0357936791019813}, {'temperature': 0.7144231018486403, 'top_p': 0.9047025679483292, 'top_k': 57, 'repetition_penalty': 1.0905945176907932}, {'temperature': 0.7252383635025537, 'top_p': 0.906268975469924, 'top_k': 57, 'repetition_penalty': 1.0874618495476611}]
#
# Debug Info:
#   Inferred Task Type: emotional
#   Current Task Target Hyperparams: {'temperature': 0.7, 'top_p': 0.9, 'top_k': 50, 'repetition_penalty': 1.1}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.7179111903132313, 'top_p': 0.9043074402876701, 'top_k': 55, 'repetition_penalty': 1.0913850046340436}
#   Current Memory State (3 entries): [{'temperature': 0.7144231018486403, 'top_p': 0.9047025679483292, 'top_k': 57, 'repetition_penalty': 1.0905945176907932}, {'temperature': 0.7252383635025537, 'top_p': 0.906268975469924, 'top_k': 57, 'repetition_penalty': 1.0874618495476611}, {'temperature': 0.7179111903132313, 'top_p': 0.9043074402876701, 'top_k': 55, 'repetition_penalty': 1.0913850046340436}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.8807572655664424, 'top_p': 0.9365278983705922, 'top_k': 86, 'repetition_penalty': 1.0269441371872499}
#   Current Memory State (3 entries): [{'temperature': 0.7252383635025537, 'top_p': 0.906268975469924, 'top_k': 57, 'repetition_penalty': 1.0874618495476611}, {'temperature': 0.7179111903132313, 'top_p': 0.9043074402876701, 'top_k': 55, 'repetition_penalty': 1.0913850046340436}, {'temperature': 0.8807572655664424, 'top_p': 0.9365278983705922, 'top_k': 86, 'repetition_penalty': 1.0269441371872499}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.8973906819382227, 'top_p': 0.9397104314128185, 'top_k': 89, 'repetition_penalty': 1.0205790991368955}
#   Current Memory State (3 entries): [{'temperature': 0.7179111903132313, 'top_p': 0.9043074402876701, 'top_k': 55, 'repetition_penalty': 1.0913850046340436}, {'temperature': 0.8807572655664424, 'top_p': 0.9365278983705922, 'top_k': 86, 'repetition_penalty': 1.0269441371872499}, {'temperature': 0.8973906819382227, 'top_p': 0.9397104314128185, 'top_k': 89, 'repetition_penalty': 1.0205790991368955}]
#
# Debug Info:
#   Inferred Task Type: emotional
#   Current Task Target Hyperparams: {'temperature': 0.7, 'top_p': 0.9, 'top_k': 50, 'repetition_penalty': 1.1}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.7396059137817896, 'top_p': 0.908054577007108, 'top_k': 58, 'repetition_penalty': 1.083890824095819}
#   Current Memory State (3 entries): [{'temperature': 0.8807572655664424, 'top_p': 0.9365278983705922, 'top_k': 86, 'repetition_penalty': 1.0269441371872499}, {'temperature': 0.8973906819382227, 'top_p': 0.9397104314128185, 'top_k': 89, 'repetition_penalty': 1.0205790991368955}, {'temperature': 0.7396059137817896, 'top_p': 0.908054577007108, 'top_k': 58, 'repetition_penalty': 1.083890824095819}]
#
# Debug Info:
#   Inferred Task Type: emotional
#   Current Task Target Hyperparams: {'temperature': 0.7, 'top_p': 0.9, 'top_k': 50, 'repetition_penalty': 1.1}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.7417753861286454, 'top_p': 0.9084292906790519, 'top_k': 58, 'repetition_penalty': 1.0831414060419964}
#   Current Memory State (3 entries): [{'temperature': 0.8973906819382227, 'top_p': 0.9397104314128185, 'top_k': 89, 'repetition_penalty': 1.0205790991368955}, {'temperature': 0.7396059137817896, 'top_p': 0.908054577007108, 'top_k': 58, 'repetition_penalty': 1.083890824095819}, {'temperature': 0.7417753861286454, 'top_p': 0.9084292906790519, 'top_k': 58, 'repetition_penalty': 1.0831414060419964}]
#
# Debug Info:
#   Inferred Task Type: creative
#   Current Task Target Hyperparams: {'temperature': 0.95, 'top_p': 0.95, 'top_k': 100, 'repetition_penalty': 1.0}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.9028771981848657, 'top_p': 0.9406194299098978, 'top_k': 90, 'repetition_penalty': 1.018761132927471}
#   Current Memory State (3 entries): [{'temperature': 0.7396059137817896, 'top_p': 0.908054577007108, 'top_k': 58, 'repetition_penalty': 1.083890824095819}, {'temperature': 0.7417753861286454, 'top_p': 0.9084292906790519, 'top_k': 58, 'repetition_penalty': 1.0831414060419964}, {'temperature': 0.9028771981848657, 'top_p': 0.9406194299098978, 'top_k': 90, 'repetition_penalty': 1.018761132927471}]
#
# Debug Info:
#   Inferred Task Type: factual
#   Current Task Target Hyperparams: {'temperature': 0.3, 'top_p': 0.85, 'top_k': 40, 'repetition_penalty': 1.2}
#   Smoothed/Final Hyperparams Used: {'temperature': 0.44842584980953004, 'top_p': 0.8707103297596057, 'top_k': 48, 'repetition_penalty': 1.1585793363065287}
#   Current Memory State (3 entries): [{'temperature': 0.7417753861286454, 'top_p': 0.9084292906790519, 'top_k': 58, 'repetition_penalty': 1.0831414060419964}, {'temperature': 0.9028771981848657, 'top_p': 0.9406194299098978, 'top_k': 90, 'repetition_penalty': 1.018761132927471}, {'temperature': 0.44842584980953004, 'top_p': 0.8707103297596057, 'top_k': 48, 'repetition_penalty': 1.1585793363065287}]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame(logs)
sns.set(style="whitegrid")

# plt avg
for param in ["temperature", "top_p", "top_k", "repetition_penalty"]:
    plt.figure(figsize=(10, 5))
    sns.lineplot(data=df, x=df.groupby("task_type").cumcount(), y=param, hue="task_type", marker="o")
    plt.title(f"Trend of {param} over Conversations")
    plt.xlabel("Conversation Index")
    plt.ylabel(param)
    plt.legend(title="Task Type")
    plt.show()

# distrib
for param in ["temperature", "top_p", "top_k", "repetition_penalty"]:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x="task_type", y=param, data=df)
    plt.title(f"Distribution of {param} by Task Type")
    plt.show()


df.to_csv("hyperparameter_log.csv", index=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# %pip install datasets --quiet
from datasets import load_dataset


ds = load_dataset("skrishna/coin_flip")

# Preview a sample
print(ds)
print(ds["test"][0])
# Out:
# Note: you may need to restart the kernel to use updated packages.
# README.md:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# train.json: 0.00B [00:00, ?B/s]
# validation.json: 0.00B [00:00, ?B/s]
# test.json: 0.00B [00:00, ?B/s]
# test_ood.json: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1333 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/3333 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['targets', 'inputs', 'targets_vec'],
#         num_rows: 20000
#     })
#     validation: Dataset({
#         features: ['targets', 'inputs', 'targets_vec'],
#         num_rows: 1333
#     })
#     test: Dataset({
#         features: ['targets', 'inputs', 'targets_vec'],
#         num_rows: 3333
#     })
# })
# {'targets': 'no', 'inputs': ' Q: A coin is heads up. rushawn flips the coin. yerania does not flip the coin. myricle does not flip the coin. jostin does not flip the coin.  Is the coin still heads up? ', 'targets_vec': [1, 0]}
